# %%
import pickle

# %%
filenames = [
    'class_accuracies_amazon_data_attrib_spurious_same_layer.pkl',
    'class_accuracies_attrib_spurious_same_layer.pkl',
]

for fn in filenames:
    with open(fn, 'rb') as f:
        data = pickle.load(f)
        print(fn)
        print(data)
        print()
# Out:
# class_accuracies_amazon_data_attrib_spurious_same_layer.pkl
# {'clean_acc': {'male / female': {'acc': 0.878000020980835, 'acc_0': 0.8920000195503235, 'acc_1': 0.8640000224113464, 'loss': 0.322265625}, 'professor / nurse': {'acc': 0.5550000071525574, 'acc_0': 0.11000000685453415, 'acc_1': 1.0, 'loss': 0.98046875}, 'male_professor / female_nurse': {'acc': 0.8080000281333923, 'acc_0': 0.6200000047683716, 'acc_1': 0.9960000514984131, 'loss': 0.37109375}, 'biased_male / biased_female': {'acc': 0.7740000486373901, 'acc_0': 0.5560000538825989, 'acc_1': 0.9920000433921814, 'loss': 0.44140625}, 'professor / nurse probe on male / female data': {'acc': 0.49900001287460327, 'acc_0': 0.05400000140070915, 'acc_1': 0.9440000653266907, 'loss': 1.390625}, 'male_professor / female_nurse probe on male / female data': {'acc': 0.6630000472068787, 'acc_0': 0.4100000262260437, 'acc_1': 0.9160000681877136, 'loss': 0.68359375}, 'biased_male / biased_female probe on male / female data': {'acc': 0.6480000019073486, 'acc_0': 0.3680000305175781, 'acc_1': 0.9280000329017639, 'loss': 0.71875}, 'male / female probe on professor / nurse data': {'acc': 0.5420000553131104, 'acc_0': 0.5560000538825989, 'acc_1': 0.527999997138977, 'loss': 0.984375}, 'male_professor / female_nurse probe on professor / nurse data': {'acc': 0.6510000228881836, 'acc_0': 0.398000031709671, 'acc_1': 0.9040000438690186, 'loss': 0.8828125}, 'biased_male / biased_female probe on professor / nurse data': {'acc': 0.6420000195503235, 'acc_0': 0.3620000183582306, 'acc_1': 0.9220000505447388, 'loss': 0.9140625}, 'male / female probe on male_professor / female_nurse data': {'acc': 0.9170000553131104, 'acc_0': 0.9320000410079956, 'acc_1': 0.9020000696182251, 'loss': 0.28125}, 'professor / nurse probe on male_professor / female_nurse data': {'acc': 0.550000011920929, 'acc_0': 0.10200000554323196, 'acc_1': 0.9980000257492065, 'loss': 0.96875}, 'biased_male / biased_female probe on male_professor / female_nurse data': {'acc': 0.7830000519752502, 'acc_0': 0.5680000185966492, 'acc_1': 0.9980000257492065, 'loss': 0.40234375}, 'male / female probe on biased_male / biased_female data': {'acc': 0.9070000648498535, 'acc_0': 0.9180000424385071, 'acc_1': 0.8960000276565552, 'loss': 0.30859375}, 'professor / nurse probe on biased_male / biased_female data': {'acc': 0.5470000505447388, 'acc_0': 0.09600000083446503, 'acc_1': 0.9980000257492065, 'loss': 0.98828125}, 'male_professor / female_nurse probe on biased_male / biased_female data': {'acc': 0.7990000247955322, 'acc_0': 0.6080000400543213, 'acc_1': 0.9900000691413879, 'loss': 0.412109375}}, 'male / female': {20: {'male / female': {'acc': 0.734000027179718, 'acc_0': 0.5580000281333923, 'acc_1': 0.9100000262260437, 'loss': 0.7734375}, 'professor / nurse': {'acc': 0.6100000143051147, 'acc_0': 0.23400001227855682, 'acc_1': 0.9860000610351562, 'loss': 0.6640625}, 'male_professor / female_nurse': {'acc': 0.7670000195503235, 'acc_0': 0.5420000553131104, 'acc_1': 0.9920000433921814, 'loss': 0.59375}, 'biased_male / biased_female': {'acc': 0.7280000448226929, 'acc_0': 0.4620000123977661, 'acc_1': 0.9940000176429749, 'loss': 0.71484375}, 'professor / nurse probe on male / female data': {'acc': 0.4740000367164612, 'acc_0': 0.09800000488758087, 'acc_1': 0.8500000238418579, 'loss': 1.09375}, 'male_professor / female_nurse probe on male / female data': {'acc': 0.6150000095367432, 'acc_0': 0.3360000252723694, 'acc_1': 0.8940000534057617, 'loss': 0.953125}, 'biased_male / biased_female probe on male / female data': {'acc': 0.5950000286102295, 'acc_0': 0.28200000524520874, 'acc_1': 0.9080000519752502, 'loss': 1.0390625}, 'male / female probe on professor / nurse data': {'acc': 0.5580000281333923, 'acc_0': 0.38200002908706665, 'acc_1': 0.734000027179718, 'loss': 1.296875}, 'male_professor / female_nurse probe on professor / nurse data': {'acc': 0.6630000472068787, 'acc_0': 0.3840000033378601, 'acc_1': 0.9420000314712524, 'loss': 1.015625}, 'biased_male / biased_female probe on professor / nurse data': {'acc': 0.6530000567436218, 'acc ...
#
# class_accuracies_attrib_spurious_same_layer.pkl
# {'clean_acc': {'male / female': {'acc': 0.956000030040741, 'acc_0': 1.0, 'acc_1': 0.9120000600814819, 'loss': 0.1669921875}, 'professor / nurse': {'acc': 0.9020000696182251, 'acc_0': 0.9920000433921814, 'acc_1': 0.812000036239624, 'loss': 0.2734375}, 'male_professor / female_nurse': {'acc': 0.9110000729560852, 'acc_0': 1.0, 'acc_1': 0.8220000267028809, 'loss': 0.2373046875}, 'biased_male / biased_female': {'acc': 0.9390000700950623, 'acc_0': 0.9880000352859497, 'acc_1': 0.89000004529953, 'loss': 0.2177734375}, 'professor / nurse probe on male / female data': {'acc': 0.4880000352859497, 'acc_0': 0.578000009059906, 'acc_1': 0.398000031709671, 'loss': 1.296875}, 'male_professor / female_nurse probe on male / female data': {'acc': 0.7150000333786011, 'acc_0': 1.0, 'acc_1': 0.4300000071525574, 'loss': 0.68359375}, 'biased_male / biased_female probe on male / female data': {'acc': 0.7620000243186951, 'acc_0': 0.9980000257492065, 'acc_1': 0.5260000228881836, 'loss': 0.53125}, 'male / female probe on professor / nurse data': {'acc': 0.5060000419616699, 'acc_0': 0.550000011920929, 'acc_1': 0.4620000123977661, 'loss': 1.375}, 'male_professor / female_nurse probe on professor / nurse data': {'acc': 0.6910000443458557, 'acc_0': 0.9760000705718994, 'acc_1': 0.406000018119812, 'loss': 0.85546875}, 'biased_male / biased_female probe on professor / nurse data': {'acc': 0.6860000491142273, 'acc_0': 0.9220000505447388, 'acc_1': 0.45000001788139343, 'loss': 0.75}, 'male / female probe on male_professor / female_nurse data': {'acc': 0.9670000672340393, 'acc_0': 1.0, 'acc_1': 0.9340000152587891, 'loss': 0.1494140625}, 'professor / nurse probe on male_professor / female_nurse data': {'acc': 0.8850000500679016, 'acc_0': 0.9900000691413879, 'acc_1': 0.7800000309944153, 'loss': 0.27734375}, 'biased_male / biased_female probe on male_professor / female_nurse data': {'acc': 0.9520000219345093, 'acc_0': 1.0, 'acc_1': 0.9040000438690186, 'loss': 0.19140625}, 'male / female probe on biased_male / biased_female data': {'acc': 0.9540000557899475, 'acc_0': 0.9820000529289246, 'acc_1': 0.9260000586509705, 'loss': 0.177734375}, 'professor / nurse probe on biased_male / biased_female data': {'acc': 0.8760000467300415, 'acc_0': 0.9760000705718994, 'acc_1': 0.7760000228881836, 'loss': 0.302734375}, 'male_professor / female_nurse probe on biased_male / biased_female data': {'acc': 0.9000000357627869, 'acc_0': 0.9880000352859497, 'acc_1': 0.812000036239624, 'loss': 0.265625}}, 'male / female': {20: {'male / female': {'acc': 0.753000020980835, 'acc_0': 1.0, 'acc_1': 0.5060000419616699, 'loss': 0.443359375}, 'professor / nurse': {'acc': 0.8670000433921814, 'acc_0': 0.9940000176429749, 'acc_1': 0.7400000095367432, 'loss': 0.3125}, 'male_professor / female_nurse': {'acc': 0.7210000157356262, 'acc_0': 1.0, 'acc_1': 0.44200003147125244, 'loss': 0.5390625}, 'biased_male / biased_female': {'acc': 0.76500004529953, 'acc_0': 0.9940000176429749, 'acc_1': 0.5360000133514404, 'loss': 0.4453125}, 'professor / nurse probe on male / female data': {'acc': 0.48900002241134644, 'acc_0': 0.6160000562667847, 'acc_1': 0.3620000183582306, 'loss': 1.328125}, 'male_professor / female_nurse probe on male / female data': {'acc': 0.6040000319480896, 'acc_0': 1.0, 'acc_1': 0.20800000429153442, 'loss': 1.078125}, 'biased_male / biased_female probe on male / female data': {'acc': 0.6260000467300415, 'acc_0': 0.9940000176429749, 'acc_1': 0.2580000162124634, 'loss': 0.8671875}, 'male / female probe on professor / nurse data': {'acc': 0.4910000264644623, 'acc_0': 0.7380000352859497, 'acc_1': 0.24400001764297485, 'loss': 1.015625}, 'male_professor / female_nurse probe on professor / nurse data': {'acc': 0.6040000319480896, 'acc_0': 1.0, 'acc_1': 0.20800000429153442, 'loss': 0.8359375}, 'biased_male / biased_female probe on professor / nurse data': {'acc': 0.6320000290870667, 'acc_0': 1.0, 'acc_1': 0.2639999985694885, 'loss': 0.6953125}, 'male / female probe on male_professor / female_nurse data': {'a ...
