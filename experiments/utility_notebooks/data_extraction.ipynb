# %% [markdown]
# To use: Move this notebook into `dictionary_learning/dictionaries` and run from there. `dictionaries` is a folder in a submodule so we don't track it currently.

# %%
raise ValueError("Don't run all")

# %%
import os
import shutil

def copy_folder_structure(src, dst, exclude_files):
    for root, dirs, files in os.walk(src):
        # Create corresponding directory in destination
        rel_path = os.path.relpath(root, src)
        dst_dir = os.path.join(dst, rel_path)
        os.makedirs(dst_dir, exist_ok=True)
        
        # Copy files, excluding those in exclude_files
        for file in files:
            if file not in exclude_files:
                src_file = os.path.join(root, file)
                dst_file = os.path.join(dst_dir, file)
                shutil.copy2(src_file, dst_file)

# Example usage
src_folder = "../../dictionary_learning/dictionaries/gemma-2-2b_sweep_topk_ctx128_ef2_0824"
dst_folder = f"{src_folder}_probe_layer_24_results"
files_to_exclude = ["ae.pt", "max_activating_inputs.pkl"]

copy_folder_structure(src_folder, dst_folder, files_to_exclude)

print(f"Folder structure copied from {src_folder} to {dst_folder}, excluding {files_to_exclude}")

# %%
import os
import shutil

## This copies all files from src to dst, excluding those in exclude_files
# Used to copy results files from a data file to the autoencoder folder

def copy_files(src: str, dst: str, exclude_files: list[str]):
    dst_files = []
    for root, dirs, files in os.walk(src):
        for file in files:
            if file not in exclude_files:
                src_file = os.path.join(root, file)
                dst_file = os.path.join(dst, os.path.relpath(src_file, src))
                os.makedirs(os.path.dirname(dst_file), exist_ok=True)
                shutil.copy2(src_file, dst_file)
                print(f"Copied: {dst_file}")
                dst_files.append(dst_file)
    if len(dst_files) == 0:
        raise ValueError(f"No files copied from {src} to {dst}")

# Paths

ae_path = "pythia70m_sweep_gated_ctx128_0730"
ae_path = "pythia70m_sweep_topk_ctx128_0730"
ae_path = "pythia70m_sweep_standard_ctx128_0712"


src_folder = f"../dictionary_learning/dictionaries/all_730_results/{ae_path}_results"
dst_folder = f"../dictionary_learning/dictionaries/{ae_path}"

# Files to always exclude
files_to_exclude = ['config.json', 'ae.pt']

# Run the copy function
copy_files(src_folder, dst_folder, files_to_exclude)

print(f"Files copied from {src_folder} to {dst_folder}")
print(f"Excluded files: {', '.join(files_to_exclude)}")

# %%
import os
import torch

def move_ae_files_to_cpu(src_folder):
    for root, dirs, files in os.walk(src_folder):
        for file in files:
            if file == 'ae.pt':
                file_path = os.path.join(root, file)
                print(f"Found ae.pt file: {file_path}")
                
                # Load the state dict
                state_dict = torch.load(file_path, map_location=torch.device('cpu'))

                # Save the state dict back to CPU
                torch.save(state_dict, file_path)
                
                print(f"Moved to CPU: {file_path}")

# Example usage
src_folder = "../dictionary_learning/dictionaries"

move_ae_files_to_cpu(src_folder)

# %%
import os
import torch

def process_ae_files(src_folder):
    for root, dirs, files in os.walk(src_folder):
        for file in files:
            if file == 'ae.pt':
                file_path = os.path.join(root, file)
                print(f"Found ae.pt file: {file_path}")
                
                # Load the state dict
                state_dict = torch.load(file_path)

                decoder = state_dict["decoder"]
                state_dict["decoder.weight"] = decoder.T

                del state_dict["decoder"]

                torch.save(state_dict, file_path)
                
                print(f"Processed: {file_path}")

# Example usage
src_folder = "../othello-trained_model-layer_5-2024-07-10_topk"


# src_folder = "../dictionary_learning/dictionaries/pythia70m_sweep_transpose_topk_ctx128_0730"

process_ae_files(src_folder)

# %%
import os
import torch

def process_ae_files(src_folder):
    for root, dirs, files in os.walk(src_folder):
        for file in files:
            if file == 'ae.pt':
                file_path = os.path.join(root, file)
                print(f"Found ae.pt file: {file_path}")
                
                # Load the state dict
                state_dict = torch.load(file_path)

                print(state_dict.keys())

                print(state_dict["decoder.weight"].shape)
                raise ValueError("Stop here")
                
                # TODO: Modify the state dict here
                
                # TODO: Save the modified state dict
                
                print(f"Processed: {file_path}")

# Example usage
src_folder = "../dictionary_learning/dictionaries/pythia70m_sweep_standard_ctx128_0712"


process_ae_files(src_folder)

# %%
import os

def process_ae_files(src_folder):
    for root, dirs, files in os.walk(src_folder):
        for file in files:
            if "class_accuracies" in file and file != "class_accuracies.pkl":
                # delete the file
                file_path = os.path.join(root, file)
                os.remove(file_path)
            elif "node_effects" in file and file != "node_effects.pkl":
                # delete the file
                file_path = os.path.join(root, file)
                os.remove(file_path)

# Example usage
src_folder = "../dictionary_learning/dictionaries"


# src_folder = "../dictionary_learning/dictionaries/pythia70m_sweep_transpose_topk_ctx128_0730"

process_ae_files(src_folder)

# %%
import os

def process_ae_files(src_folder):
    for root, dirs, files in os.walk(src_folder):
        for file in files:
            if "max_activating_inputs" not in file and ".pkl" in file:
                # delete the file
                file_path = os.path.join(root, file)
                os.remove(file_path)

# Example usage
src_folder = "../dictionary_learning/dictionaries"


# src_folder = "../dictionary_learning/dictionaries/pythia70m_sweep_transpose_topk_ctx128_0730"

process_ae_files(src_folder)

# %%
import os
import shutil

def copy_ae_files(src_folder):
    for root, dirs, files in os.walk(src_folder):
        for file in files:
            if file == "class_accuracies.pkl":
                # Copy the file with a new name
                src_path = os.path.join(root, file)
                dst_path = os.path.join(root, "class_accuracies_2epochs.pkl")
                shutil.copy2(src_path, dst_path)
                print(f"Copied {src_path} to {dst_path}")
            elif file == "node_effects.pkl":
                # Copy the file with a new name
                src_path = os.path.join(root, file)
                dst_path = os.path.join(root, "node_effects_2epochs.pkl")
                shutil.copy2(src_path, dst_path)
                print(f"Copied {src_path} to {dst_path}")

# Example usage
src_folder = "../dictionary_learning/dictionaries/gemma-2-2b_sweep_standard_ctx128_0816"

# Uncomment the line below if you want to use the more specific path
# src_folder = "../dictionary_learning/dictionaries/pythia70m_sweep_transpose_topk_ctx128_0730"

copy_ae_files(src_folder)

# %%
import os

def delete_checkpoint_files(src_folder: str, files_to_delete: list[str]):
    for root, dirs, files in os.walk(src_folder):
        for file in files:

            if file in files_to_delete:
                # delete the file
                file_path = os.path.join(root, file)
                os.remove(file_path)

# Example usage
src_folder = "../dictionary_learning/dictionaries"

files_to_delete = ["ae_14646.pt", "ae_24410.pt", "ae_34174.pt", "ae_39056.pt", "ae_43938.pt", "ae_48820.pt"]


# src_folder = "../dictionary_learning/dictionaries/pythia70m_sweep_transpose_topk_ctx128_0730"

delete_checkpoint_files(src_folder, files_to_delete)
